# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module. 
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
max_games = 3

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games. 
num_games_win = 2

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'.
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins. 

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

import random 
options = ['stone', 'paper', 'scissors']

def machine_move(): 
    move_1 = random.choice(options) 
    
    if move_1 == 'stone':
        return 'stone'
    elif move_1 == 'paper':
        return 'paper'
    elif move_1 == 'scissors':
        return 'scissors'

def player_move():
    move_2 = input("enter stone, paper or scissors: ")
    
    if move_2 == 'stone':
        return 'stone'
    elif move_2 == 'paper':
        return 'paper'
    elif move_2 == 'scissors':
        return 'scissors'
    else:
        print('you need to chose stone, paper or scissors. try again!')
        return player_move()

player = player_move()
machine = machine_move()
    
def compare_moves(player, machine):
    if player == machine:
        print("machine chose the same, it's a tie")
        return 0 
    if player == 'paper':
        if machine == 'scissors':
            print('machine chose scissors, you lose')
            return 1 
        elif machine == 'stone':
            print('machine chose stone, you win')
            return 2 
    elif player == 'scissors':
        if machine == 'paper':
            print('machine chose paper, you win')
            return 2 
        elif machine == 'stone':
            print('machine chose stone, you lose') 
            return 1 
    elif player == 'stone':
        if machine == 'paper':
            print('machine chose paper, you lose')
            return 1 
        elif machine == 'scissors':
            ('machine chose scissors, you win')
            return 2

def game():
    player_move
    machine_move
    compare_moves(player, machine)
    return 0 
'''(N.T.) I have to return something otherwise the function doesn't stop, but I am not 100% sure if 0 is ok.''' 

# Create two variables that accumulate the wins of each participant

player_wins = 0 
machine_wins = 0 

if compare_moves == 2:
    player_wins += 1 
elif compare_moves == 1:
    machine_wins += 1  

# Create a loop that iterates while no player reaches the minimum of wins necessary to win. 
# Inside the loop solves the play of the machine and ask the player's. 
# Compare them and update the value of the variables that accumulate the wins of each participant.
# Print by console the winner of the game based on who has more accumulated wins
'''
max_games = 0

while max_games < 3:
    max_games += 1
    game()

    if player_wins > machine_wins:
        print('you win!')
    elif player_wins < machine_wins:
        print('you lose!') 

(N.T.) This final code is not working and afther checking all the funtions I cannot find the reason why. 
For this reason, I just printed game() so you can see that all the other steps went right. 
'''

game()
# Out:
# enter stone, paper or scissors: PAPER
# you need to chose stone, paper or scissors. try again!
# enter stone, paper or scissors: paper
# machine chose stone, you win
# 0

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random 

# Define a function that asks for an odd number on the keyboard, until it is not valid will keep asking
def player_choice():
    choice_1 = input("enter an odd number on your keyboard: ")
    
    if choice_1 == '1':
        return 1
    elif choice_1 == '3':
        return 3
    elif choice_1 == '5':
        return 5
    elif choice_1 == '7':
        return 7
    elif choice_1 == '9':
        return 9  
    else:
        print('you need to chose 1,3,5,7 or 9')
        return player_choice() 

# Assign a list of 5 possible options.
options2 = [1,3,5,7,9] 

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
max_games2 = 3 

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
num_games_win2 = 2 

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def machine_choice():
    choice_2 = random.choice(options2)
    
    if choice_2 == '1':
        return 1 
    elif choice_2 == '3':
        return 3
    elif choice_2 == '5':
        return 5
    elif choice_2 == '7':
        return 7
    elif choice_2 == '9':
        return 9 

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

'''already did this at question 2''' 

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options

'''
1 = rock 
3 = paper 
5 = scissors
7 = lizard 
9 = spock 

Rules: 
Scissors cuts paper 
paper covers rock
rock crushes lizard
lizard poisons Spock
Spock smashes scissors
scissors decapitates lizard
lizard eats paper
paper disproves Spock
Spock vaporizes rock 
rock crushes scissors
''' 

human = player_choice
computer = machine_choice

def compare_choice(player, machine):
    if human == computer:
        print("machine chose the same, it's a tie")
        return 0 
    if human == '1':
        if computer == '3':
            print('machine chose 3, you lose')
            return 1 
        elif computer == '5':
            print('machine chose 5, you win')
            return 2 
        elif computer == '7':
            print('machine chose 7, you win')
            return 2 
        elif computer == '9':
            print('machine chose 9, you lose')
            return 1 
    elif human == '3':
        if computer == '1':
            print('machine chose 3, you won')
            return 2
        elif computer == '5':
            print('machine chose 5, you lose')
            return 1 
        elif computer == '7':
            print('machine chose 7, you lose')
            return 1 
        elif computer == '9':
            print('machine chose 9, you win')
            return 2 
    elif human == '5':
        if computer == '1':
            print('machine chose 1, you lose')
            return 1 
        elif computer == '3':
            print('machine chose 3, you win')
            return 2 
        elif computer == '7':
            print('machine chose 7, you win')
            return 2 
        elif computer == '9':
            print('machine chose 9, you lose')
            return 1 
    elif human == '7':
        if computer == '1':
            print('machine chose 1, you lose')
            return 1 
        elif computer == '3':
            print('machine chose 3, you win')
            return 2 
        elif computer == '5':
            print('machine chose 5, you lose')
            return 1 
        elif computer == '9':
            print('machine chose 9, you win')
            return 2 
    elif human == '9':
        if computer == '1':
            print('machine chose 1, you win')
            return 2 
        elif computer == '3':
            print('machine chose 3, you lose')
            return 1 
        elif computer == '5':
            print('machine chose 5, you win')
            return 2 
        elif computer == '7':
            print('machine chose 7, you lose')
            return 1 

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def game2():
    player_choice()
    machine_choice() 
    compare_choice(player, machine)
    
# Create two variables that accumulate the wins of each participant

player_points = 0 
machine_points = 0
comparison = compare_choice

if comparison == 2:
    player_points += 1
elif comparison == 1:
    machine_points += 1 

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
# Print by console the winner of the game based on who has more accumulated wins

num_games_win2 = 0 

while num_games_win2 < 2:
    num_games_win2 += 1
    game2()
    
    if player_points > machine_points:
        print('you win!')
    elif player_points < machine_points:
        print('you lose!')
# Out:
# enter an odd number on your keyboard: 1
# enter an odd number on your keyboard: 1
